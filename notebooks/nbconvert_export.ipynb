# %% [markdown]
# # NBconvert Export
#
# A short snippet to export all Jupyter Lab notebooks in a directory into Markdown with associated image files.

# %%
import glob

# %% [markdown]
# ## All notebooks

# %%
#directory = ''
#glob.os.chdir(directory)
notebooks = [file for file in glob.glob("*.ipynb")]
notebooks[0:3] # List few of them
# Out:
# ['anonymous_functions.ipynb',
#  'anscombe_quartet.ipynb',
#  'antecedent_precipitation_index.ipynb']

# %%
for file in notebooks:
    # !jupyter nbconvert $file --to markdown --output-dir ../docs

print("Done!")
# Out:
# [NbConvertApp] Converting notebook anonymous_functions.ipynb to markdown
# [NbConvertApp] Writing 3643 bytes to ../docs/anonymous_functions.md
# [NbConvertApp] Converting notebook anscombe_quartet.ipynb to markdown
# [NbConvertApp] Support files will be in anscombe_quartet_files/
# [NbConvertApp] Making directory ../docs/anscombe_quartet_files
# [NbConvertApp] Writing 6445 bytes to ../docs/anscombe_quartet.md
# [NbConvertApp] Converting notebook antecedent_precipitation_index.ipynb to markdown
# [NbConvertApp] Support files will be in antecedent_precipitation_index_files/
# [NbConvertApp] Making directory ../docs/antecedent_precipitation_index_files
# [NbConvertApp] Making directory ../docs/antecedent_precipitation_index_files
# [NbConvertApp] Making directory ../docs/antecedent_precipitation_index_files
# [NbConvertApp] Making directory ../docs/antecedent_precipitation_index_files
# [NbConvertApp] Making directory ../docs/antecedent_precipitation_index_files
# [NbConvertApp] Writing 25212 bytes to ../docs/antecedent_precipitation_index.md
# [NbConvertApp] Converting notebook atmospheric_carbon_dioxide.ipynb to markdown
# [NbConvertApp] Support files will be in atmospheric_carbon_dioxide_files/
# [NbConvertApp] Making directory ../docs/atmospheric_carbon_dioxide_files
# [NbConvertApp] Making directory ../docs/atmospheric_carbon_dioxide_files
# [NbConvertApp] Making directory ../docs/atmospheric_carbon_dioxide_files
# [NbConvertApp] Making directory ../docs/atmospheric_carbon_dioxide_files
# [NbConvertApp] Making directory ../docs/atmospheric_carbon_dioxide_files
# [NbConvertApp] Making directory ../docs/atmospheric_carbon_dioxide_files
# [NbConvertApp] Making directory ../docs/atmospheric_carbon_dioxide_files
# [NbConvertApp] Writing 13059 bytes to ../docs/atmospheric_carbon_dioxide.md
# [NbConvertApp] Converting notebook atmospheric_water_deficit.ipynb to markdown
# [NbConvertApp] Support files will be in atmospheric_water_deficit_files/
# [NbConvertApp] Making directory ../docs/atmospheric_water_deficit_files
# [NbConvertApp] Making directory ../docs/atmospheric_water_deficit_files
# [NbConvertApp] Writing 9246 bytes to ../docs/atmospheric_water_deficit.md
# [NbConvertApp] Converting notebook birthday_paradox.ipynb to markdown
# [NbConvertApp] Writing 3469 bytes to ../docs/birthday_paradox.md
# [NbConvertApp] Converting notebook blackjack.ipynb to markdown
# [NbConvertApp] Writing 3558 bytes to ../docs/blackjack.md
# [NbConvertApp] Converting notebook calculator_examples.ipynb to markdown
# [NbConvertApp] Writing 1071 bytes to ../docs/calculator_examples.md
# [NbConvertApp] Converting notebook capillarity.ipynb to markdown
# [NbConvertApp] Writing 3440 bytes to ../docs/capillarity.md
# [NbConvertApp] Converting notebook cdf_matching.ipynb to markdown
# [NbConvertApp] Support files will be in cdf_matching_files/
# [NbConvertApp] Making directory ../docs/cdf_matching_files
# [NbConvertApp] Making directory ../docs/cdf_matching_files
# [NbConvertApp] Making directory ../docs/cdf_matching_files
# [NbConvertApp] Making directory ../docs/cdf_matching_files
# [NbConvertApp] Making directory ../docs/cdf_matching_files
# [NbConvertApp] Writing 6610 bytes to ../docs/cdf_matching.md
# [NbConvertApp] Converting notebook central_dogma_multiple_polypeptides.ipynb to markdown
# [NbConvertApp] Writing 6664 bytes to ../docs/central_dogma_multiple_polypeptides.md
# [NbConvertApp] Converting notebook central_dogma_single_polypeptide.ipynb to markdown
# [NbConvertApp] Writing 12538 bytes to ../docs/central_dogma_single_polypeptide.md
# [NbConvertApp] Converting notebook climate_classification.ipynb to markdown
# [NbConvertApp] Writing 2058 bytes to ../docs/climate_classification.md
# [NbConvertApp] Converting notebook comparative_anatomy_for_loops.ipynb to markdown
# [NbConvertApp] Writing 2630 bytes to ../docs/comparative_anatomy_for_loops.md
# [NbConvertApp] Converting notebook comparative_anatomy_functions.ipynb to markdown
# [NbConvertApp] Writing 1325 bytes to ../docs/comparative_anatomy_functions.md
# [NbConvertApp] Converting notebook comparative_anatomy_if_statement.ipynb to markdown
# [NbConvertApp] Writing 2028 bytes to ../docs/comparative_anatomy_if_statement.md
# [NbConvertApp] Converting notebook coronavirus.ipynb to markdown
# [NbConvertApp] Support files will be in coronavirus_files/
# [NbConvertApp] Making directory ../docs/coronavirus_files
# [NbConvertApp] Making directory ../docs/coronavirus_files
# [NbConvertApp] Making directory ../docs/coronavirus_files
# [NbConvertApp] Writing 1703755 bytes to ../docs/coronavirus.md
# [NbConvertApp] Converting notebook cumulative_rainfall.ipynb to markdown
# [NbConvertApp] Support files will be in cumulative_rainfall_files/
# [NbConvertApp] Making directory ../docs/cumulative_rainfall_files
# [NbConvertApp] Writing 4924 bytes to ../docs/cumulative_rainfall.md
# [NbConvertApp] Converting notebook data_structures.ipynb to markdown
# [NbConvertApp] Writing 8553 bytes to ../docs/data_structures.md
# [NbConvertApp] Converting notebook data_types.ipynb to markdown
# [NbConvertApp] Writing 6780 bytes to ../docs/data_types.md
# [NbConvertApp] Converting notebook datetime_module.ipynb to markdown
# [NbConvertApp] Writing 3507 bytes to ../docs/datetime_module.md
# [NbConvertApp] Converting notebook day_of_week.ipynb to markdown
# [NbConvertApp] Writing 3146 bytes to ../docs/day_of_week.md
# [NbConvertApp] Converting notebook day_of_year.ipynb to markdown
# [NbConvertApp] Writing 2002 bytes to ../docs/day_of_year.md
# [NbConvertApp] Converting notebook debye.ipynb to markdown
# [NbConvertApp] Support files will be in debye_files/
# [NbConvertApp] Making directory ../docs/debye_files
# [NbConvertApp] Writing 2577 bytes to ../docs/debye.md
# [NbConvertApp] Converting notebook denoise_passive_neutron_counts.ipynb to markdown
# [NbConvertApp] Support files will be in denoise_passive_neutron_counts_files/
# [NbConvertApp] Making directory ../docs/denoise_passive_neutron_counts_files
# [NbConvertApp] Making directory ../docs/denoise_passive_neutron_counts_files
# [NbConvertApp] Making directory ../docs/denoise_passive_neutron_counts_files
# [NbConvertApp] Making directory ../docs/denoise_passive_neutron_counts_files
# [NbConvertApp] Writing 7387 bytes to ../docs/denoise_passive_neutron_counts.md
# [NbConvertApp] Converting notebook denoise_yield_monitor.ipynb to markdown
# [NbConvertApp] Support files will be in denoise_yield_monitor_files/
# [NbConvertApp] Making directory ../docs/denoise_yield_monitor_files
# [NbConvertApp] Making directory ../docs/denoise_yield_monitor_files
# [NbConvertApp] Making directory ../docs/denoise_yield_monitor_files
# [NbConvertApp] Making directory ../docs/denoise_yield_monitor_files
# [NbConvertApp] Making directory ../docs/denoise_yield_monitor_files
# [NbConvertApp] Making directory ../docs/denoise_yield_monitor_files
# [NbConvertApp] Writing 16970 bytes to ../docs/denoise_yield_monitor.md
# [NbConvertApp] Converting notebook drydowns_from_timeseries.ipynb to markdown
# [NbConvertApp] Support files will be in drydowns_from_timeseries_files/
# [NbConvertApp] Making directory ../docs/drydowns_from_timeseries_files
# [NbConvertApp] Making directory ../docs/drydowns_from_timeseries_files
# [NbConvertApp] Making directory ../docs/drydowns_from_timeseries_files
# [NbConvertApp] Making directory ../docs/drydowns_from_timeseries_files
# [NbConvertApp] Making directory ../docs/drydowns_from_timeseries_files
# [NbConvertApp] Writing 14075 bytes to ../docs/drydowns_from_timeseries.md
# [NbConvertApp] Converting notebook error_handling.ipynb to markdown
# [NbConvertApp] Writing 3001 bytes to ../docs/error_handling.md
# [NbConvertApp] Converting notebook error_metrics.ipynb to markdown
# [NbConvertApp] Writing 5293 bytes to ../docs/error_metrics.md
# [NbConvertApp] Converting notebook euclidean_distance.ipynb to markdown
# [NbConvertApp] Support files will be in euclidean_distance_files/
# [NbConvertApp] Making directory ../docs/euclidean_distance_files
# [NbConvertApp] Writing 3691 bytes to ../docs/euclidean_distance.md
# [NbConvertApp] Converting notebook exponential_filter.ipynb to markdown
# [NbConvertApp] Support files will be in exponential_filter_files/
# [NbConvertApp] Making directory ../docs/exponential_filter_files
# [NbConvertApp] Making directory ../docs/exponential_filter_files
# [NbConvertApp] Writing 12200 bytes to ../docs/exponential_filter.md
# [NbConvertApp] Converting notebook fibonacci_sequence.ipynb to markdown
# [NbConvertApp] Writing 1697 bytes to ../docs/fibonacci_sequence.md
# [NbConvertApp] Converting notebook field_management_zones.ipynb to markdown
# [NbConvertApp] Support files will be in field_management_zones_files/
# [NbConvertApp] Making directory ../docs/field_management_zones_files
# [NbConvertApp] Making directory ../docs/field_management_zones_files
# [NbConvertApp] Writing 11796 bytes to ../docs/field_management_zones.md
# [NbConvertApp] Converting notebook fill_missing_data.ipynb to markdown
# [NbConvertApp] Support files will be in fill_missing_data_files/
# [NbConvertApp] Making directory ../docs/fill_missing_data_files
# [NbConvertApp] Making directory ../docs/fill_missing_data_files
# [NbConvertApp] Making directory ../docs/fill_missing_data_files
# [NbConvertApp] Making directory ../docs/fill_missing_data_files
# [NbConvertApp] Writing 13517 bytes to ../docs/fill_missing_data.md
# [NbConvertApp] Converting notebook for_loops.ipynb to markdown
# [NbConvertApp] Writing 5426 bytes to ../docs/for_loops.md
# [NbConvertApp] Converting notebook frontier_function.ipynb to markdown
# [NbConvertApp] Support files will be in frontier_function_files/
# [NbConvertApp] Making directory ../docs/frontier_function_files
# [NbConvertApp] Making directory ../docs/frontier_function_files
# [NbConvertApp] Making directory ../docs/frontier_function_files
# [NbConvertApp] Writing 19509 bytes to ../docs/frontier_function.md
# [NbConvertApp] Converting notebook functions.ipynb to markdown
# [NbConvertApp] Writing 10460 bytes to ../docs/functions.md
# [NbConvertApp] Converting notebook game_of_life.ipynb to markdown
# [NbConvertApp] Support files will be in game_of_life_files/
# [NbConvertApp] Making directory ../docs/game_of_life_files
# [NbConvertApp] Making directory ../docs/game_of_life_files
# [NbConvertApp] Making directory ../docs/game_of_life_files
# [NbConvertApp] Writing 7750 bytes to ../docs/game_of_life.md
# [NbConvertApp] Converting notebook glob_module.ipynb to markdown
# [NbConvertApp] Writing 3646 bytes to ../docs/glob_module.md
# [NbConvertApp] Converting notebook handy_functions.ipynb to markdown
# [NbConvertApp] Writing 1966 bytes to ../docs/handy_functions.md
# [NbConvertApp] Converting notebook hangman.ipynb to markdown
# [NbConvertApp] Writing 2788 bytes to ../docs/hangman.md
# [NbConvertApp] Converting notebook hello_world.ipynb to markdown
# [NbConvertApp] Writing 1974 bytes to ../docs/hello_world.md
# [NbConvertApp] Converting notebook help_resources.ipynb to markdown
# [NbConvertApp] Writing 2148 bytes to ../docs/help_resources.md
# [NbConvertApp] Converting notebook if_statement.ipynb to markdown
# [NbConvertApp] Writing 1861 bytes to ../docs/if_statement.md
# [NbConvertApp] Converting notebook image_analysis_canopeo.ipynb to markdown
# [NbConvertApp] Support files will be in image_analysis_canopeo_files/
# [NbConvertApp] Making directory ../docs/image_analysis_canopeo_files
# [NbConvertApp] Making directory ../docs/image_analysis_canopeo_files
# [NbConvertApp] Writing 4733 bytes to ../docs/image_analysis_canopeo.md
# [NbConvertApp] Converting notebook image_analysis_contact_angle.ipynb to markdown
# [NbConvertApp] Support files will be in image_analysis_contact_angle_files/
# [NbConvertApp] Making directory ../docs/image_analysis_contact_angle_files
# [NbConvertApp] Making directory ../docs/image_analysis_contact_angle_files
# [NbConvertApp] Making directory ../docs/image_analysis_contact_angle_files
# [NbConvertApp] Making directory ../docs/image_analysis_contact_angle_files
# [NbConvertApp] Making directory ../docs/image_analysis_contact_angle_files
# [NbConvertApp] Making directory ../docs/image_analysis_contact_angle_files
# [NbConvertApp] Writing 3092 bytes to ../docs/image_analysis_contact_angle.md
# [NbConvertApp] Converting notebook image_analysis_count_seeds.ipynb to markdown
# [NbConvertApp] Support files will be in image_analysis_count_seeds_files/
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Making directory ../docs/image_analysis_count_seeds_files
# [NbConvertApp] Writing 5441 bytes to ../docs/image_analysis_count_seeds.md
# [NbConvertApp] Converting notebook import_tabular_data.ipynb to markdown
# [NbConvertApp] Writing 1873 bytes to ../docs/import_tabular_data.md
# [NbConvertApp] Converting notebook importing_modules.ipynb to markdown
# [NbConvertApp] Writing 1870 bytes to ../docs/importing_modules.md
# [NbConvertApp] Converting notebook indexing_and_slicing_lists.ipynb to markdown
# [NbConvertApp] Writing 2516 bytes to ../docs/indexing_and_slicing_lists.md
# [NbConvertApp] Converting notebook inputs.ipynb to markdown
# [NbConvertApp] Writing 2866 bytes to ../docs/inputs.md
# [NbConvertApp] Converting notebook leaky_bucket.ipynb to markdown
# [NbConvertApp] Support files will be in leaky_bucket_files/
# [NbConvertApp] Making directory ../docs/leaky_bucket_files
# [NbConvertApp] Making directory ../docs/leaky_bucket_files
# [NbConvertApp] Making directory ../docs/leaky_bucket_files
# [NbConvertApp] Making directory ../docs/leaky_bucket_files
# [NbConvertApp] Writing 6399 bytes to ../docs/leaky_bucket.md
# [NbConvertApp] Converting notebook leap_year.ipynb to markdown
# [NbConvertApp] Writing 736 bytes to ../docs/leap_year.md
# [NbConvertApp] Converting notebook logistic_growth.ipynb to markdown
# [NbConvertApp] Support files will be in logistic_growth_files/
# [NbConvertApp] Making directory ../docs/logistic_growth_files
# [NbConvertApp] Making directory ../docs/logistic_growth_files
# [NbConvertApp] Making directory ../docs/logistic_growth_files
# [NbConvertApp] Making directory ../docs/logistic_growth_files
# [NbConvertApp] Writing 3937 bytes to ../docs/logistic_growth.md
# [NbConvertApp] Converting notebook lotka_volterra.ipynb to markdown
# [NbConvertApp] Support files will be in lotka_volterra_files/
# [NbConvertApp] Making directory ../docs/lotka_volterra_files
# [NbConvertApp] Writing 2964 bytes to ../docs/lotka_volterra.md
# [NbConvertApp] Converting notebook mass_volume_relationships.ipynb to markdown
# [NbConvertApp] Writing 3777 bytes to ../docs/mass_volume_relationships.md
# [NbConvertApp] Converting notebook matching_dna_strand.ipynb to markdown
# [NbConvertApp] Writing 10356 bytes to ../docs/matching_dna_strand.md
# [NbConvertApp] Converting notebook math_module.ipynb to markdown
# [NbConvertApp] Writing 4454 bytes to ../docs/math_module.md
# [NbConvertApp] Converting notebook matplotlib_module.ipynb to markdown
# [NbConvertApp] Support files will be in matplotlib_module_files/
# [NbConvertApp] Making directory ../docs/matplotlib_module_files
# [NbConvertApp] Making directory ../docs/matplotlib_module_files
# [NbConvertApp] Making directory ../docs/matplotlib_module_files
# [NbConvertApp] Making directory ../docs/matplotlib_module_files
# [NbConvertApp] Making directory ../docs/matplotlib_module_files
# [NbConvertApp] Making directory ../docs/matplotlib_module_files
# [NbConvertApp] Writing 14506 bytes to ../docs/matplotlib_module.md
# [NbConvertApp] Converting notebook mixing_model.ipynb to markdown
# [NbConvertApp] Support files will be in mixing_model_files/
# [NbConvertApp] Making directory ../docs/mixing_model_files
# [NbConvertApp] Making directory ../docs/mixing_model_files
# [NbConvertApp] Making directory ../docs/mixing_model_files
# [NbConvertApp] Writing 6183 bytes to ../docs/mixing_model.md
# [NbConvertApp] Converting notebook monty_hall.ipynb to markdown
# [NbConvertApp] Writing 9435 bytes to ../docs/monty_hall.md
# [NbConvertApp] Converting notebook morse_code_guessing_game.ipynb to markdown
# [NbConvertApp] Writing 4547 bytes to ../docs/morse_code_guessing_game.md
# [NbConvertApp] Converting notebook morse_decoder.ipynb to markdown
# [NbConvertApp] Writing 8131 bytes to ../docs/morse_decoder.md
# [NbConvertApp] Converting notebook morse_encoder.ipynb to markdown
# [NbConvertApp] Writing 17787 bytes to ../docs/morse_encoder.md
# [NbConvertApp] Converting notebook nbconvert_export.ipynb to markdown
# [NbConvertApp] Writing 1983 bytes to ../docs/nbconvert_export.md
# [NbConvertApp] Converting notebook nearest_station.ipynb to markdown
# [NbConvertApp] Writing 4837 bytes to ../docs/nearest_station.md
# [NbConvertApp] Converting notebook neutron_probe_calibration.ipynb to markdown
# [NbConvertApp] Support files will be in neutron_probe_calibration_files/
# [NbConvertApp] Making directory ../docs/neutron_probe_calibration_files
# [NbConvertApp] Making directory ../docs/neutron_probe_calibration_files
# [NbConvertApp] Writing 6013 bytes to ../docs/neutron_probe_calibration.md
# [NbConvertApp] Converting notebook newton_law_cooling.ipynb to markdown
# [NbConvertApp] Support files will be in newton_law_cooling_files/
# [NbConvertApp] Making directory ../docs/newton_law_cooling_files
# [NbConvertApp] Writing 4024 bytes to ../docs/newton_law_cooling.md
# [NbConvertApp] Converting notebook noisy_wave.ipynb to markdown
# [NbConvertApp] Support files will be in noisy_wave_files/
# [NbConvertApp] Making directory ../docs/noisy_wave_files
# [NbConvertApp] Writing 1385 bytes to ../docs/noisy_wave.md
# [NbConvertApp] Converting notebook numpy_module.ipynb to markdown
# [NbConvertApp] Writing 8741 bytes to ../docs/numpy_module.md
# [NbConvertApp] Converting notebook objects_and_classes.ipynb to markdown
# [NbConvertApp] Writing 10318 bytes to ../docs/objects_and_classes.md
# [NbConvertApp] Converting notebook optimal_nitrogen_rate.ipynb to markdown
# [NbConvertApp] Support files will be in optimal_nitrogen_rate_files/
# [NbConvertApp] Making directory ../docs/optimal_nitrogen_rate_files
# [NbConvertApp] Making directory ../docs/optimal_nitrogen_rate_files
# [NbConvertApp] Making directory ../docs/optimal_nitrogen_rate_files
# [NbConvertApp] Making directory ../docs/optimal_nitrogen_rate_files
# [NbConvertApp] Writing 3858 bytes to ../docs/optimal_nitrogen_rate.md
# [NbConvertApp] Converting notebook os_module.ipynb to markdown
# [NbConvertApp] Writing 3366 bytes to ../docs/os_module.md
# [NbConvertApp] Converting notebook pandas_mesonet_stations.ipynb to markdown
# [NbConvertApp] Writing 25023 bytes to ../docs/pandas_mesonet_stations.md
# [NbConvertApp] Converting notebook pandas_module.ipynb to markdown
# [NbConvertApp] Writing 31112 bytes to ../docs/pandas_module.md
# [NbConvertApp] Converting notebook pedotransfer_saxton_rawls.ipynb to markdown
# [NbConvertApp] Support files will be in pedotransfer_saxton_rawls_files/
# [NbConvertApp] Making directory ../docs/pedotransfer_saxton_rawls_files
# [NbConvertApp] Writing 8126 bytes to ../docs/pedotransfer_saxton_rawls.md
# [NbConvertApp] Converting notebook photoperiod_math_module.ipynb to markdown
# [NbConvertApp] Writing 1541 bytes to ../docs/photoperiod_math_module.md
# [NbConvertApp] Converting notebook photoperiod_numpy_module.ipynb to markdown
# [NbConvertApp] Support files will be in photoperiod_numpy_module_files/
# [NbConvertApp] Making directory ../docs/photoperiod_numpy_module_files
# [NbConvertApp] Writing 4131 bytes to ../docs/photoperiod_numpy_module.md
# [NbConvertApp] Converting notebook plant_available_water.ipynb to markdown
# [NbConvertApp] Support files will be in plant_available_water_files/
# [NbConvertApp] Making directory ../docs/plant_available_water_files
# [NbConvertApp] Writing 2657 bytes to ../docs/plant_available_water.md
# [NbConvertApp] Converting notebook plotting_bokeh.ipynb to markdown
# /opt/anaconda3/lib/python3.7/site-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['application/javascript', 'application/vnd.bokehjs_load.v0+json']) is not able to be represented.
#   mimetypes=output.keys())
# /opt/anaconda3/lib/python3.7/site-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['application/javascript', 'application/vnd.bokehjs_exec.v0+json']) is not able to be represented.
#   mimetypes=output.keys())
# [NbConvertApp] Writing 5471 bytes to ../docs/plotting_bokeh.md
# [NbConvertApp] Converting notebook population_dynamics.ipynb to markdown
# [NbConvertApp] Support files will be in population_dynamics_files/
# [NbConvertApp] Making directory ../docs/population_dynamics_files
# [NbConvertApp] Writing 3683 bytes to ../docs/population_dynamics.md
# [NbConvertApp] Converting notebook precipitation_metrics.ipynb to markdown
# [NbConvertApp] Support files will be in precipitation_metrics_files/
# [NbConvertApp] Making directory ../docs/precipitation_metrics_files
# [NbConvertApp] Making directory ../docs/precipitation_metrics_files
# [NbConvertApp] Making directory ../docs/precipitation_metrics_files
# [NbConvertApp] Making directory ../docs/precipitation_metrics_files
# [NbConvertApp] Writing 12419 bytes to ../docs/precipitation_metrics.md
# [NbConvertApp] Converting notebook proctor_test.ipynb to markdown
# [NbConvertApp] Support files will be in proctor_test_files/
# [NbConvertApp] Making directory ../docs/proctor_test_files
# [NbConvertApp] Making directory ../docs/proctor_test_files
# [NbConvertApp] Making directory ../docs/proctor_test_files
# [NbConvertApp] Writing 5392 bytes to ../docs/proctor_test.md
# [NbConvertApp] Converting notebook radiocarbon_dating.ipynb to markdown
# [NbConvertApp] Support files will be in radiocarbon_dating_files/
# [NbConvertApp] Making directory ../docs/radiocarbon_dating_files
# [NbConvertApp] Writing 3328 bytes to ../docs/radiocarbon_dating.md
# [NbConvertApp] Converting notebook random_groups_of_people.ipynb to markdown
# [NbConvertApp] Writing 4606 bytes to ../docs/random_groups_of_people.md
# [NbConvertApp] Converting notebook random_module.ipynb to markdown
# [NbConvertApp] Writing 4531 bytes to ../docs/random_module.md
# [NbConvertApp] Converting notebook random_plots.ipynb to markdown
# [NbConvertApp] Writing 3746 bytes to ../docs/random_plots.md
# [NbConvertApp] Converting notebook random_walk.ipynb to markdown
# [NbConvertApp] Support files will be in random_walk_files/
# [NbConvertApp] Making directory ../docs/random_walk_files
# [NbConvertApp] Making directory ../docs/random_walk_files
# [NbConvertApp] Making directory ../docs/random_walk_files
# [NbConvertApp] Writing 2983 bytes to ../docs/random_walk.md
# [NbConvertApp] Converting notebook reaction_diffusion.ipynb to markdown
# [NbConvertApp] Support files will be in reaction_diffusion_files/
# [NbConvertApp] Making directory ../docs/reaction_diffusion_files
# [NbConvertApp] Making directory ../docs/reaction_diffusion_files
# [NbConvertApp] Writing 5124 bytes to ../docs/reaction_diffusion.md
# [NbConvertApp] Converting notebook regular_expressions.ipynb to markdown
# [NbConvertApp] Writing 4023 bytes to ../docs/regular_expressions.md
# [NbConvertApp] Converting notebook root_depth.ipynb to markdown
# [NbConvertApp] Support files will be in root_depth_files/
# [NbConvertApp] Making directory ../docs/root_depth_files
# [NbConvertApp] Writing 14382 bytes to ../docs/root_depth.md
# [NbConvertApp] Converting notebook sample_logger.ipynb to markdown
# [NbConvertApp] Writing 6098 bytes to ../docs/sample_logger.md
# [NbConvertApp] Converting notebook sedimentation_time.ipynb to markdown
# [NbConvertApp] Writing 1810 bytes to ../docs/sedimentation_time.md
# [NbConvertApp] Converting notebook segmented_lake.ipynb to markdown
# [NbConvertApp] Support files will be in segmented_lake_files/
# [NbConvertApp] Making directory ../docs/segmented_lake_files
# [NbConvertApp] Making directory ../docs/segmented_lake_files
# [NbConvertApp] Making directory ../docs/segmented_lake_files
# [NbConvertApp] Making directory ../docs/segmented_lake_files
# [NbConvertApp] Making directory ../docs/segmented_lake_files
# [NbConvertApp] Making directory ../docs/segmented_lake_files
# [NbConvertApp] Making directory ../docs/segmented_lake_files
# [NbConvertApp] Making directory ../docs/segmented_lake_files
# [NbConvertApp] Writing 6531 bytes to ../docs/segmented_lake.md
# [NbConvertApp] Converting notebook soil_cracks_detection.ipynb to markdown
# [NbConvertApp] Support files will be in soil_cracks_detection_files/
# [NbConvertApp] Making directory ../docs/soil_cracks_detection_files
# [NbConvertApp] Making directory ../docs/soil_cracks_detection_files
# [NbConvertApp] Making directory ../docs/soil_cracks_detection_files
# [NbConvertApp] Making directory ../docs/soil_cracks_detection_files
# [NbConvertApp] Making directory ../docs/soil_cracks_detection_files
# [NbConvertApp] Writing 5118 bytes to ../docs/soil_cracks_detection.md
# [NbConvertApp] Converting notebook soil_moisture_map.ipynb to markdown
# [NbConvertApp] Support files will be in soil_moisture_map_files/
# [NbConvertApp] Making directory ../docs/soil_moisture_map_files
# [NbConvertApp] Writing 3955 bytes to ../docs/soil_moisture_map.md
# [NbConvertApp] Converting notebook soil_respiration.ipynb to markdown
# [NbConvertApp] Support files will be in soil_respiration_files/
# [NbConvertApp] Making directory ../docs/soil_respiration_files
# [NbConvertApp] Writing 4981 bytes to ../docs/soil_respiration.md
# [NbConvertApp] Converting notebook soil_temperature.ipynb to markdown
# [NbConvertApp] Support files will be in soil_temperature_files/
# [NbConvertApp] Making directory ../docs/soil_temperature_files
# [NbConvertApp] Making directory ../docs/soil_temperature_files
# [NbConvertApp] Making directory ../docs/soil_temperature_files
# [NbConvertApp] Making directory ../docs/soil_temperature_files
# [NbConvertApp] Making directory ../docs/soil_temperature_files
# [NbConvertApp] Making directory ../docs/soil_temperature_files
# [NbConvertApp] Writing 15745 bytes to ../docs/soil_temperature.md
# [NbConvertApp] Converting notebook soil_temperature_model.ipynb to markdown
# /opt/anaconda3/lib/python3.7/site-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['application/javascript', 'application/vnd.bokehjs_load.v0+json']) is not able to be represented.
#   mimetypes=output.keys())
# /opt/anaconda3/lib/python3.7/site-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['application/javascript', 'application/vnd.bokehjs_exec.v0+json']) is not able to be represented.
#   mimetypes=output.keys())
# [NbConvertApp] Support files will be in soil_temperature_model_files/
# [NbConvertApp] Making directory ../docs/soil_temperature_model_files
# [NbConvertApp] Making directory ../docs/soil_temperature_model_files
# [NbConvertApp] Making directory ../docs/soil_temperature_model_files
# [NbConvertApp] Writing 6633 bytes to ../docs/soil_temperature_model.md
# [NbConvertApp] Converting notebook soil_textural_class.ipynb to markdown
# [NbConvertApp] Writing 2322 bytes to ../docs/soil_textural_class.md
# [NbConvertApp] Converting notebook soil_water_deficit_classification.ipynb to markdown
# [NbConvertApp] Support files will be in soil_water_deficit_classification_files/
# [NbConvertApp] Making directory ../docs/soil_water_deficit_classification_files
# [NbConvertApp] Writing 7186 bytes to ../docs/soil_water_deficit_classification.md
# [NbConvertApp] Converting notebook soil_water_retention_curve.ipynb to markdown
# [NbConvertApp] Support files will be in soil_water_retention_curve_files/
# [NbConvertApp] Making directory ../docs/soil_water_retention_curve_files
# [NbConvertApp] Making directory ../docs/soil_water_retention_curve_files
# [NbConvertApp] Making directory ../docs/soil_water_retention_curve_files
# [NbConvertApp] Writing 3791 bytes to ../docs/soil_water_retention_curve.md
# [NbConvertApp] Converting notebook soil_water_storage.ipynb to markdown
# [NbConvertApp] Support files will be in soil_water_storage_files/
# [NbConvertApp] Making directory ../docs/soil_water_storage_files
# [NbConvertApp] Making directory ../docs/soil_water_storage_files
# [NbConvertApp] Making directory ../docs/soil_water_storage_files
# [NbConvertApp] Writing 8238 bytes to ../docs/soil_water_storage.md
# [NbConvertApp] Converting notebook sorting_numbers.ipynb to markdown
# [NbConvertApp] Writing 9290 bytes to ../docs/sorting_numbers.md
# [NbConvertApp] Converting notebook statistics_module.ipynb to markdown
# [NbConvertApp] Support files will be in statistics_module_files/
# [NbConvertApp] Making directory ../docs/statistics_module_files
# [NbConvertApp] Writing 3903 bytes to ../docs/statistics_module.md
# [NbConvertApp] Converting notebook stats_2d_interpolation.ipynb to markdown
# [NbConvertApp] Support files will be in stats_2d_interpolation_files/
# [NbConvertApp] Making directory ../docs/stats_2d_interpolation_files
# [NbConvertApp] Making directory ../docs/stats_2d_interpolation_files
# [NbConvertApp] Writing 5342 bytes to ../docs/stats_2d_interpolation.md
# [NbConvertApp] Converting notebook stats_curve_fitting_exp.ipynb to markdown
# [NbConvertApp] Support files will be in stats_curve_fitting_exp_files/
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_exp_files
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_exp_files
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_exp_files
# [NbConvertApp] Writing 8580 bytes to ../docs/stats_curve_fitting_exp.md
# [NbConvertApp] Converting notebook stats_curve_fitting_wave.ipynb to markdown
# [NbConvertApp] Support files will be in stats_curve_fitting_wave_files/
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_wave_files
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_wave_files
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_wave_files
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_wave_files
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_wave_files
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_wave_files
# [NbConvertApp] Making directory ../docs/stats_curve_fitting_wave_files
# [NbConvertApp] Writing 6027 bytes to ../docs/stats_curve_fitting_wave.md
# [NbConvertApp] Converting notebook stats_descriptive.ipynb to markdown
# [NbConvertApp] Support files will be in stats_descriptive_files/
# [NbConvertApp] Making directory ../docs/stats_descriptive_files
# [NbConvertApp] Making directory ../docs/stats_descriptive_files
# [NbConvertApp] Making directory ../docs/stats_descriptive_files
# [NbConvertApp] Writing 1719 bytes to ../docs/stats_descriptive.md
# [NbConvertApp] Converting notebook stats_linear_fit.ipynb to markdown
# [NbConvertApp] Support files will be in stats_linear_fit_files/
# [NbConvertApp] Making directory ../docs/stats_linear_fit_files
# [NbConvertApp] Making directory ../docs/stats_linear_fit_files
# [NbConvertApp] Making directory ../docs/stats_linear_fit_files
# [NbConvertApp] Writing 11626 bytes to ../docs/stats_linear_fit.md
# [NbConvertApp] Converting notebook stats_multiple_linear_regression.ipynb to markdown
# [NbConvertApp] Support files will be in stats_multiple_linear_regression_files/
# [NbConvertApp] Making directory ../docs/stats_multiple_linear_regression_files
# [NbConvertApp] Making directory ../docs/stats_multiple_linear_regression_files
# [NbConvertApp] Writing 9047 bytes to ../docs/stats_multiple_linear_regression.md
# [NbConvertApp] Converting notebook strings.ipynb to markdown
# [NbConvertApp] Writing 6854 bytes to ../docs/strings.md
# [NbConvertApp] Converting notebook sympy_module.ipynb to markdown
# [NbConvertApp] Support files will be in sympy_module_files/
# [NbConvertApp] Making directory ../docs/sympy_module_files
# [NbConvertApp] Making directory ../docs/sympy_module_files
# [NbConvertApp] Writing 1762 bytes to ../docs/sympy_module.md
# [NbConvertApp] Converting notebook thermal_time.ipynb to markdown
# [NbConvertApp] Support files will be in thermal_time_files/
# [NbConvertApp] Making directory ../docs/thermal_time_files
# [NbConvertApp] Making directory ../docs/thermal_time_files
# [NbConvertApp] Writing 19462 bytes to ../docs/thermal_time.md
# [NbConvertApp] Converting notebook time_module.ipynb to markdown
# [NbConvertApp] Writing 5313 bytes to ../docs/time_module.md
# [NbConvertApp] Converting notebook url_ks_mesonet.ipynb to markdown
# [NbConvertApp] Support files will be in url_ks_mesonet_files/
# [NbConvertApp] Making directory ../docs/url_ks_mesonet_files
# [NbConvertApp] Writing 7970 bytes to ../docs/url_ks_mesonet.md
# [NbConvertApp] Converting notebook url_nasa_api.ipynb to markdown
# [NbConvertApp] Support files will be in url_nasa_api_files/
# [NbConvertApp] Making directory ../docs/url_nasa_api_files
# [NbConvertApp] Making directory ../docs/url_nasa_api_files
# [NbConvertApp] Writing 15836 bytes to ../docs/url_nasa_api.md
# [NbConvertApp] Converting notebook url_ok_mesonet.ipynb to markdown
# /opt/anaconda3/lib/python3.7/site-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['application/javascript', 'application/vnd.bokehjs_load.v0+json']) is not able to be represented.
#   mimetypes=output.keys())
# /opt/anaconda3/lib/python3.7/site-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['application/javascript', 'application/vnd.bokehjs_exec.v0+json']) is not able to be represented.
#   mimetypes=output.keys())
# [NbConvertApp] Writing 4982 bytes to ../docs/url_ok_mesonet.md
# [NbConvertApp] Converting notebook url_uscrn.ipynb to markdown
# [NbConvertApp] Support files will be in url_uscrn_files/
# [NbConvertApp] Making directory ../docs/url_uscrn_files
# [NbConvertApp] Writing 12397 bytes to ../docs/url_uscrn.md
# [NbConvertApp] Converting notebook vapor_pressure_deficit.ipynb to markdown
# [NbConvertApp] Support files will be in vapor_pressure_deficit_files/
# [NbConvertApp] Making directory ../docs/vapor_pressure_deficit_files
# [NbConvertApp] Writing 3694 bytes to ../docs/vapor_pressure_deficit.md
# [NbConvertApp] Converting notebook venn_diagrams.ipynb to markdown
# [NbConvertApp] Support files will be in venn_diagrams_files/
# [NbConvertApp] Making directory ../docs/venn_diagrams_files
# [NbConvertApp] Writing 4145 bytes to ../docs/venn_diagrams.md
# [NbConvertApp] Converting notebook weather_generator.ipynb to markdown
# [NbConvertApp] Support files will be in weather_generator_files/
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Making directory ../docs/weather_generator_files
# [NbConvertApp] Writing 25013 bytes to ../docs/weather_generator.md
# [NbConvertApp] Converting notebook wheat_phenology.ipynb to markdown
# [NbConvertApp] Writing 4992 bytes to ../docs/wheat_phenology.md
# [NbConvertApp] Converting notebook wheat_potential_biomass.ipynb to markdown
# [NbConvertApp] Support files will be in wheat_potential_biomass_files/
# [NbConvertApp] Making directory ../docs/wheat_potential_biomass_files
# [NbConvertApp] Making directory ../docs/wheat_potential_biomass_files
# [NbConvertApp] Making directory ../docs/wheat_potential_biomass_files
# [NbConvertApp] Making directory ../docs/wheat_potential_biomass_files
# [NbConvertApp] Making directory ../docs/wheat_potential_biomass_files
# [NbConvertApp] Making directory ../docs/wheat_potential_biomass_files
# [NbConvertApp] Writing 23780 bytes to ../docs/wheat_potential_biomass.md
# [NbConvertApp] Converting notebook while_loops.ipynb to markdown
# [NbConvertApp] Writing 4147 bytes to ../docs/while_loops.md

# %% [markdown]
# ## Single notebook

# %%
# Define a single notebook
specific_notebook = 'stats_linear_fit.ipynb'

# Export single notebook
# !jupyter nbconvert $specific_notebook --to markdown --output-dir ../docs
# Out:
# [NbConvertApp] Converting notebook stats_linear_fit.ipynb to markdown
# [NbConvertApp] Support files will be in stats_linear_fit_files/
# [NbConvertApp] Making directory ../docs/stats_linear_fit_files
# [NbConvertApp] Making directory ../docs/stats_linear_fit_files
# [NbConvertApp] Making directory ../docs/stats_linear_fit_files
# [NbConvertApp] Writing 9999 bytes to ../docs/stats_linear_fit.md
