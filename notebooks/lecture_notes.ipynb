# %% [markdown]
# # Course Intro
# * Learn about you, your expectations, and set the scope of the class.
# * Download software required for the class
#
# * Course assumes no prior programming knowledge and is intended for beginners that probably attempeted to get started with coding based on online tutorials and somehow were not able follow.
# * Mistakes and frustration will part of the routine. Be patient and remian determined.
# * Variable pace to ensure that you understand a concept before moving forward.
#
# * Live coding sessions: risky, things may not work, we might need to stop, but the idea is to code an explain to you why I'm writing these lines.
#
# * Ask: who has tried to self-teach coding before?
#
#
# # Dreyfus scale of skill acquisition:
#
# Novice | Competent | Proficient | Expert | Mastery
#
# **Competent-Proficient**: use of programming languages to automate tasks, analyze datasets, and create a reproducible and logical blueprint of scientific claims.
#
#
# # Let students to introduce themselves (15 min)
# * Full name
# * Degree
# * Research topic
# * Why are you enrolled in this class?
# * Windows/Mac/Linux Operating System
# * Take notes about student observations and answers
#
#
# # Share the opinion of others people about coding (10 min)
# * Show code.org video: <https://youtu.be/nKIu9yen5nc>
# * Show code.org website and some stats: <https://code.org/promote/ks>
# * Ask students to read inspirational quotes (quotes come from the website, not the video)
# * Experience interviewing at the Climate Corporation (similar offices and atmosphere)
# * Relate to what M. Zuckerberg says about building something small and then adding more to it (0:47)
#
# # Programming stats
# * Computing occupations are the number 1 source of all new wages in the U.S.
# * Computing occupations make up over half of all projected new jobs in STEM fields.
# * Kansas currently has 2,313 open computing jobs
# * Kansas had only 338 computer science graduates in 2015; only 14% were female.
# * The average salary for a computing occupation in KS is 77,116, higher than average salary in the state (44,570).
#
#
# # Role of coding in my career (5 min)
# * Coding is one of the most important skills that I learned in gradaute school
# * Before coding I was locked into analysis of variance and significant differences. Coding enabled spatio-temporal analysis, numerical simulation of physically-based processes, curve fitting and parameter optimization
# * Coding forces you to think logically, break down a large problem into smaller steps, and requires attention about seemingly irrelevant details
# * Track the work and reasoning of students and colleagues. Underrated tool for advising
# * Create something out of thin air
#
# # Brief history of coding languages in Science (10 min)
# Make a timeline. Source: <https://www.wikiwand.com/en/Timeline_of_programming_languages>
#     * 1958 - Fortran II
#     * 1964 - BASIC (show soil physics book)
#     * 1970 - Pascal
#     * 1972 - C (Low level, base of other languages: C++,Java,JavaScript,C#,PHP, Python)
#     * 1976 - SAS
#     * 1978 - Matlab (https://www.mathworks.com/products/matlab.html)
#     * 1989 - Python (https://www.python.org/)
#     * 1990 - HTML (physicist Tim Berners-Lee, a contractor at CERN, used for documentation)
#     * 1993 - R (https://www.r-project.org/)
#     * 1995 - Java, PHP, Javascript, Ruby
#     * 2012 - Julia (https://julialang.org/)
#
# # Why Python?
# * Multi-purpose language (analyze data, create software, websites, etc.)
# * Most popular language in science, large community, lots of online help and books
# * Free,
# * Syntax somewhat similar to that of Matlab
#
# # Course syllabus (10 min)
# * Handle each student a copy of the syllabus
# * Allocate 10 minutes to read and explain the format of the course
# * Emphasize class requirements: laptop, laptop charger, anaconda package, and github account
#
# # Course goals
# * construct effective, well documented, and error free scripts and functions.
# * find information independently for self-teaching and problem solving.
# * use programming in graduate project.
#
# # Show class material
# * Access through soil water processes website: <https://soilwater.ksu.edu>
# * Access directly through Github: <https://github.com/andres-patrignani/introcoding-spring-2019>
#
# # Anaconda package (rest of the class time)
# * Download anaconda at: https://www.anaconda.com/
# * Review installation of Anaconda package (open installation tutorial)
# * Visit with students and troubleshoot problems
#
# # Install Git
# * Go to: https://git-scm.com/downloads
# * Select Windows/Mac OS (Macs already have Git)
# * Follow the installer. Use default settings
# * Test if you have Git by openning the command window/terminal and typing: git --version
#
# # Install Github
# * Create a Github account at: https://github.com/
# * Recommend firstname-lastname
#
# # Reading assignment
# * Read paper by Philip Guo 2013
# * Read paper by Sandve et al 2013
# * Next class we will discuss reproducible research and hopefully write our first line of code.

# %% [markdown]
# # Reproducible research
#
# ## What is reproducible research
# * Ability to re-create results, tables, figures, and document analyses.
# * Data --> figure
# * Publish data, code, and figures
# * Aggregate steps into a single environment: Python, Matlab, R
# * Traditional research flow
#     Retrieve data from a website or collect field/ lab data (only step that cannot be
#     Store data: MS Excel (in reproducible research we try to store
#     Analyze tabular data: Excel, SigmaPlot
#     Analyze spatial data: ArcGIS
#     Statistical analysis: SAS
#     Image analysis: Sigma Scan
#     Insert citations: EndNote, Mendeley
#     Write manuscript: MS Word, LaTeX
# * Then we need to implement corrections and we need to repeat all the steps again. Programming languages offer a blueprint
# * Takes more time at the beginning, but saves time in the long run, it becomes reproducible, and documents the steps.
#
# ## Discuss articles about reproducible research
# Ten Simple Rules for Reproducible Computational Research
# Geir Kjetil Sandve , Anton Nekrutenko, James Taylor, Eivind Hovig
# Published: October 24, 2013
# DOI: https://doi.org/10.1371/journal.pcbi.1003285
# https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1003285
#
# "Let us change our traditional attitude to the construction of programs: Instead of imagining that our main task is to instruct a computer what to do, let us concentrate rather on explaining to humans what we want the computer to do."
#
# — Donald E. Knuth, Literate Programming, 1984
#
# ## Present a framework for writing code
# * Show coding framework
# * Example was created while I was a graduate student

# %% [markdown]
# # 3. Use Git and Github
#
# Goal is to create a repository and upload files
# ## Git
# * Version control
#
# ## Github
# * A sophisticaed and useful graphical user interface for git
# * Tour: code, project, wiki
#
# ## Anaconda
# * Jupyter notebooks
# * Jupyter lab
# * Spyder: Development environmnet similar to Matlab
#
# ## Jupyter lab
# * Getting started
