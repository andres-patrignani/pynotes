# %% [markdown]
# # Subplots
#
# A way of condensing figures using different subplot layouts

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
dirname = '/Users/andrespatrignani/Dropbox/Teaching/Scientific programming/introcoding-spring-2019/Datasets/'
filename = 'global_wheat.csv'

# %%
# Load wheat data
df = pd.read_csv(dirname + filename)
df.head(5)
# Out:
#    year  Argentina_area_has  Argentina_production_ton  Argentina_yield_hg_ha  \
# 0  1961             4420900                   5725000                  12950
# 1  1962             3744700                   5700000                  15222
# 2  1963             5676000                   8940000                  15751
# 3  1964             6135400                  11260000                  18353
# 4  1965             4601200                   6079000                  13212
#
#    Australia_area_has  Australia_production_ton  Australia_yield_hg_ha  \
# 0             5958110                   6727190                  11291
# 1             6664680                   8352910                  12533
# 2             6666680                   8924460                  13387
# 3             7251500                  10037000                  13841
# 4             7087980                   7067060                   9970
#
#    Canada_area_has  Canada_production_ton  Canada_yield_hg_ha       ...        \
# 0         10245000                7713000                7529       ...
# 1         10853000               15393000               14183       ...
# 2         11156000               19691000               17651       ...
# 3         12018000               16349000               13604       ...
# 4         11453000               17674000               15432       ...
#
#    Germany_yield_hg_ha  Mexico_area_has  Mexico_production_ton  \
# 0                28607           836538                1401910
# 1                33898           747728                1455260
# 2                33934           819210                1702990
# 3                34845           818325                2203070
# 4                32321           858259                2150350
#
#    Mexico_yield_hg_ha  UK_area_has  UK_production_ton  UK_yield_hg_ha  \
# 0               16758       739000            2614000           35372
# 1               19462       913000            3974000           43527
# 2               20788       780000            3046000           39051
# 3               26922       893000            3793000           42475
# 4               25055      1026000            4171000           40653
#
#    US_area_has  US_production_ton  US_yield_hg_ha
# 0     20870000           33539000           16070
# 1     17680000           29718000           16809
# 2     18415000           31211900           16949
# 3     20138000           34928000           17344
# 4     20056000           35805000           17853
#
# [5 rows x 28 columns]

# %%
plt.figure()

plt.subplot(2,1,1)
plt.plot(df.year,df.Argentina_yield_hg_ha)
plt.ylabel('Yield kg/ha')

plt.subplot(2,1,2)
plt.plot(df.year,df.UK_yield_hg_ha)
plt.ylabel('Yield kg/ha')

plt.show()
# The subplot() command specifies numrows, numcols, plot_number
