# %% [markdown]
# # NBconvert Export
#
# A short snippet to export all Jupyter Lab notebooks in a directory into Markdown with associated image files.

# %%
import glob

# %% [markdown]
# ## All notebooks

# %%
#directory = ''
#glob.os.chdir(directory)
notebooks = [file for file in glob.glob("*.ipynb")]
notebooks[0:3] # List few of them
# Out:
# ['anonymous_functions.ipynb',
#  'anscombe_quartet.ipynb',
#  'antecedent_precipitation_index.ipynb']

# %%
for file in notebooks:
    # !jupyter nbconvert $file --to markdown --output-dir ../docs

print("Done!")

# %% [markdown]
# ## Single notebook

# %%
# Define a single notebook
specific_notebook = 'stats_linear_fit.ipynb'

# Export single notebook
# !jupyter nbconvert $specific_notebook --to markdown --output-dir ../docs
# Out:
# [NbConvertApp] Converting notebook stats_linear_fit.ipynb to markdown
# [NbConvertApp] Support files will be in stats_linear_fit_files/
# [NbConvertApp] Making directory ../docs/stats_linear_fit_files
# [NbConvertApp] Making directory ../docs/stats_linear_fit_files
# [NbConvertApp] Making directory ../docs/stats_linear_fit_files
# [NbConvertApp] Writing 15614 bytes to ../docs/stats_linear_fit.md

# %% [markdown]
# # To HTML

# %%
specific_notebook = 'population_dynamics.ipynb'

# !jupyter nbconvert $specific_notebook --to html --template basic --output-dir ../docs
# Out:
# [NbConvertApp] Converting notebook population_dynamics.ipynb to html
# [NbConvertApp] Writing 61110 bytes to ../docs/population_dynamics.html

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# affine                             2.3.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# appnope                            0.1.0
# appscript                          1.0.1
# asn1crypto                         1.3.0
# astroid                            2.3.3
# astropy                            4.0
# atomicwrites                       1.3.0
# attrs                              19.3.0
# Babel                              2.8.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.6.1
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# basemap                            1.2.0
# beautifulsoup4                     4.8.2
# bitarray                           1.2.1
# bkcharts                           0.2
# bleach                             3.1.0
# bokeh                              1.4.0
# boto                               2.49.0
# Bottleneck                         1.3.1
# bqplot                             0.12.3
# certifi                            2019.11.28
# cffi                               1.14.0
# chardet                            3.0.4
# Click                              7.0
# click-plugins                      1.1.1
# cligj                              0.5.0
# cloudpickle                        1.3.0
# clyent                             1.2.2
# colorama                           0.4.3
# conda                              4.8.2
# conda-build                        3.18.11
# conda-package-handling             1.6.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       2.8
# cycler                             0.10.0
# Cython                             0.29.15
# cytoolz                            0.10.1
# dask                               2.10.1
# decorator                          4.4.1
# defusedxml                         0.6.0
# distributed                        2.10.0
# docopt                             0.6.2
# docutils                           0.16
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# Fiona                              1.8.13.post1
# Flask                              1.1.1
# fsspec                             0.6.2
# future                             0.18.2
# geopandas                          0.7.0
# gevent                             1.4.0
# glob2                              0.7
# gmpy2                              2.0.8
# greenlet                           0.4.15
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.0.1
# hypothesis                         5.5.4
# idna                               2.8
# imageio                            2.6.1
# imagesize                          1.2.0
# importlib-metadata                 1.5.0
# ipykernel                          5.1.4
# ipython                            7.12.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              4.3.21
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.16.0
# Jinja2                             2.11.1
# joblib                             0.14.1
# json5                              0.8.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     5.3.4
# jupyter-console                    6.1.0
# jupyter-core                       4.6.1
# jupyterlab                         1.2.6
# jupyterlab-server                  1.0.6
# keyring                            21.1.0
# kiwisolver                         1.1.0
# lazy-object-proxy                  1.4.3
# libarchive-c                       2.8
# lief                               0.9.0
# llvmlite                           0.31.0
# locket                             0.2.0
# lxml                               4.5.0
# marisa-trie                        0.7.5
# MarkupSafe                         1.1.1
# matplotlib                         3.1.3
# matplotlib-venn                    0.11.5
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.0.15
# mkl-random                         1.1.0
# mkl-service                        2.3.0
# mock                               4.0.1
# more-itertools                     8.2.0
# mpmath                             1.1.0
# msgpack                            0.6.1
# multipledispatch                   0.6.0
# munch                              2.5.0
# navigator-updater                  0.2.1
# nbconvert                          5.6.1
# nbformat                           4.4.0
# nbinteract                         0.2.4
# networkx                           2.4
# nltk                               3.4.5
# nose                               1.3.7
# notebook                           6.0.3
# numba                              0.48.0
# numexpr                            2.7.1
# numpy                              1.18.1
# numpydoc                           0.9.2
# olefile                            0.46
# openpyxl                           3.0.3
# packaging                          20.1
# pandas                             1.0.1
# pandocfilters                      1.4.2
# parso                              0.6.1
# partd                              1.1.0
# path                               13.1.0
# pathlib2                           2.3.5
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             7.0.0
# pip                                20.0.2
# pkginfo                            1.5.0.1
# plotly                             4.5.2
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.7.1
# prompt-toolkit                     3.0.3
# psutil                             5.6.7
# ptyprocess                         0.6.0
# py                                 1.8.1
# pycodestyle                        2.5.0
# pycosat                            0.6.3
# pycparser                          2.19
# pycrypto                           2.6.1
# pycurl                             7.43.0.5
# pyflakes                           2.1.1
# Pygments                           2.5.2
# pylint                             2.4.4
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.6
# pyproj                             2.4.1
# pyrsistent                         0.15.7
# pyshp                              2.1.0
# PySocks                            1.7.1
# pytest                             5.3.5
# pytest-arraydiff                   0.3
# pytest-astropy                     0.8.0
# pytest-astropy-header              0.1.2
# pytest-doctestplus                 0.5.0
# pytest-openfiles                   0.4.0
# pytest-remotedata                  0.3.2
# python-dateutil                    2.8.1
# pytz                               2019.3
# PyWavelets                         1.1.1
# PyYAML                             5.3
# pyzmq                              18.1.1
# QtAwesome                          0.6.1
# qtconsole                          4.6.0
# QtPy                               1.9.0
# rasterio                           1.1.3
# requests                           2.22.0
# retrying                           1.3.3
# rope                               0.16.0
# ruamel-yaml                        0.15.87
# scikit-image                       0.16.2
# scikit-learn                       0.22.1
# scipy                              1.4.1
# seaborn                            0.10.0
# Send2Trash                         1.5.0
# setuptools                         45.2.0.post20200210
# Shapely                            1.7.0
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.14.0
# sklearn                            0.0
# snowballstemmer                    2.0.0
# snuggs                             1.4.7
# sortedcollections                  1.1.2
# sortedcontainers                   2.1.0
# soupsieve                          1.9.5
# spanish-sentiment-analysis         1.0.0
# Sphinx                             2.4.0
# sphinxcontrib-applehelp            1.0.1
# sphinxcontrib-devhelp              1.0.1
# sphinxcontrib-htmlhelp             1.0.2
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.2
# sphinxcontrib-serializinghtml      1.1.3
# sphinxcontrib-websupport           1.2.0
# spyder                             3.3.6
# spyder-kernels                     0.5.2
# SQLAlchemy                         1.3.13
# statsmodels                        0.11.0
# sympy                              1.5.1
# tables                             3.6.1
# tblib                              1.6.0
# terminado                          0.8.3
# testpath                           0.4.4
# toolz                              0.10.0
# tornado                            6.0.3
# tqdm                               4.42.1
# traitlets                          4.3.3
# traittypes                         0.2.1
# unicodecsv                         0.14.1
# urllib3                            1.25.8
# wcwidth                            0.1.8
# webencodings                       0.5.1
# Werkzeug                           1.0.0
# wheel                              0.34.2
# widgetsnbextension                 3.5.1
# wrapt                              1.11.2
# wurlitzer                          2.0.0
# xlrd                               1.2.0
# XlsxWriter                         1.2.7
# xlwings                            0.17.1
# xlwt                               1.3.0
# zict                               1.0.0
# zipp                               2.2.0
# Note: you may need to restart the kernel to use updated packages.
